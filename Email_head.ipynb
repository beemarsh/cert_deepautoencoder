# %%
import pandas as pd
df = pd.read_csv("processed_email.csv",nrows=100000)
df
# Out:
#                              id  user   pc  \
# 0      {R3I7-S4TX96FG-8219JWFF}   588  553
# 1      {R0R9-E4GL59IK-2907OSWJ}   675  665
# 2      {G2B2-A8XY58CP-2847ZJZL}   588  553
# 3      {A3A9-F4TH89AA-8318GFGK}   588  553
# 4      {E8B7-C8FZ88UF-2946RUQQ}   675  665
# ...                         ...   ...  ...
# 99995  {W9K2-B3LH17SK-2688DLQO}   758  353
# 99996  {U9W8-A4QG01IJ-0131IHMP}   823  955
# 99997  {U4P1-O3CI14RY-8953EIGP}   845  961
# 99998  {W4I8-J7NN61FG-2643QGAW}   163  696
# 99999  {R0P7-T0LO30WQ-0127DUZG}   271  292
#
#                                                       to  \
# 0      Dean.Flynn.Hines@dtaa.com;Wade_Harrison@lockhe...
# 1                            Odonnell-Gage@bellsouth.net
# 2                             Penelope_Colon@netzero.com
# 3                              Judith_Hayden@comcast.net
# 4      Bond-Raymond@verizon.net;Alea_Ferrell@msn.com;...
# ...                                                  ...
# ...
